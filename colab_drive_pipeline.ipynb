# %% [markdown]
# # A股 Colab → GitHub → Google Drive → Scrapling 探测版
#
# 这个 notebook 做一件事：运行 GitHub 里的 Scrapling 脚本，访问同花顺页面，把探测结果保存到 Google Drive。

# %% [markdown]
# ## 第 1 步：挂载 Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 第 2 步：设置数据保存目录

# %%
import os

os.environ['A_STOCK_DRIVE_DIR'] = '/content/drive/MyDrive/a_stock_data'
print('数据保存目录:', os.environ['A_STOCK_DRIVE_DIR'])

# %% [markdown]
# ## 第 3 步：拉取 GitHub 代码

# %%
GITHUB_REPO = 'https://github.com/lee001-hai/a-stock-colab-drive-tools.git'

# !rm -rf /content/a-stock-colab-drive-tools
# !git clone {GITHUB_REPO} /content/a-stock-colab-drive-tools

# %% [markdown]
# ## 第 4 步：安装 Scrapling

# %%
# !pip install -q -r /content/a-stock-colab-drive-tools/requirements.txt

# %% [markdown]
# ## 第 5 步：运行同花顺 Scrapling 探测

# %%
# %cd /content/a-stock-colab-drive-tools
# !python run_once.py
